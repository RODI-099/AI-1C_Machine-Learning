# %% [markdown]
# #classification va regressionga 4 ta misol

# %%
import pandas as pd

# 1. Hayvonlar dataset
df1 = pd.DataFrame([
    ["miaw", "small", 15, "yes", 0],
    ["woof", "medium", 25, "yes", 1],
    ["squeak", "small", 20, "yes", 2],
    ["moo", "large", 10, "no", 3],
    ["miaw", "small", 12, "yes", 0],
    ["woof", "large", 30, "yes", 1],
    ["squeak", "small", 18, "yes", 2],
    ["moo", "large", 8, "no", 3],
], columns=["sound", "size", "speed", "domestic", "class"])

# 2. Ob-havo dataset
df2 = pd.DataFrame([
    [30, 40, 10, "workday", 0],
    [18, 85, 20, "weekend", 1],
    [-5, 75, 15, "workday", 2],
    [15, 60, 5, "workday", 3],
    [32, 35, 8, "weekend", 0],
    [20, 90, 25, "workday", 1],
    [-2, 80, 10, "weekend", 2],
    [17, 55, 7, "weekend", 3],
], columns=["temperature", "humidity", "wind_speed", "day_type", "class"])

# 3. Talabalar dataset
df3 = pd.DataFrame([
    [95, 90, "yes", 20, 0],
    [80, 85, "yes", 21, 1],
    [65, 70, "no", 22, 2],
    [40, 60, "no", 23, 3],
    [90, 95, "yes", 20, 0],
    [75, 80, "yes", 21, 1],
    [60, 75, "no", 22, 2],
    [35, 50, "no", 23, 3],
], columns=["score", "attendance", "project", "age", "class"])

# 4. Ichimliklar dataset
df4 = pd.DataFrame([
    [70, 2, "no", "brown", 0],
    [80, 1, "no", "black", 1],
    [10, 8, "no", "orange", 2],
    [5, 0, "no", "clear", 3],
    [65, 3, "no", "brown", 0],
    [75, 2, "no", "black", 1],
    [8, 9, "no", "orange", 2],
    [4, 0, "no", "clear", 3],
], columns=["temperature", "sweetness", "carbonated", "color", "class"])


import pandas as pd

# 1. Uy narxlari dataset
df1 = pd.DataFrame([
    [1200, 3, 2, 10, 250000],
    [1500, 4, 3, 5, 320000],
    [800, 2, 1, 20, 180000],
    [2000, 5, 4, 2, 450000],
    [1000, 3, 2, 15, 220000],
], columns=["area_sqft", "bedrooms", "bathrooms", "age_years", "price"])

# 2. Mashina yoqilg'i sarfi dataset
df2 = pd.DataFrame([
    [1500, 4, 120, 15],
    [1800, 6, 140, 12],
    [1000, 3, 100, 18],
    [2000, 8, 160, 10],
    [1300, 4, 110, 16],
], columns=["engine_cc", "cylinders", "horsepower", "fuel_efficiency_mpg"])

# 3. Talabalar baholari dataset
df3 = pd.DataFrame([
    [85, 90, 80, 88],
    [70, 75, 65, 72],
    [95, 92, 98, 96],
    [60, 65, 55, 62],
    [80, 85, 78, 82],
], columns=["math_score", "science_score", "english_score", "final_grade"])

# 4. Harorat va muzqaymoq savdosi dataset
df4 = pd.DataFrame([
    [30, 200],
    [25, 180],
    [35, 220],
    [20, 150],
    [40, 250],
], columns=["temperature_celsius", "ice_cream_sales"])

# Datasetlarni ko'rish
print("Uy narxlari dataset:")
print(df1)

print("\nMashina yoqilg'i sarfi dataset:")
print(df2)

print("\nTalabalar baholari dataset:")
print(df3)

print("\nHarorat va muzqaymoq savdosi dataset:")
print(df4)

# %% [markdown]
# Otgan mavzu boyicha tushunchalarim:
# O`tgan mavzuda biz Supervisez machine Learning va uning turlarga bo`linishini o`rgandik va shuningdek kaggle va githubdan datasetlarni to`plashni ko`rib chiqdik.
# Shuningdek Pythonda datasetlarni o`qish va kutubhonalardan foydalanishni o`rgandik
